# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomistong/ExcelPythonACD/blob/main/ExcelPython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
/content/sample_data/california_housing_test.csv

# %%
# 基本匯入
import pandas as pd
df = pd.read_excel(r"/content/sample_data/data/test.xlsx")
df
# Out:
#    編號  年齡 性別       註冊時間
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09
# 2  A3  47  女 2018-08-10
# 3  A4  41  男 2018-08-11

# %%
filenamestr=""

# %%
path="/content/sample_data/data/test.xlsx"

# %%
filenamestr=path+"text.xlsx"

# %%
path
# Out:
# '/content/sample_data/data/'

# %%
filenamestr
# Out:
# '/content/sample_data/data/text.xlsx'

# %%
df_sheetname=pd.read_excel(path,sheet_name="工作表1")

# %%
df_sheetname
# Out:
#    編號  年齡 性別       註冊時間
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09
# 2  A3  47  女 2018-08-10
# 3  A4  41  男 2018-08-11

# %%
df
# Out:
#    編號  年齡 性別       註冊時間
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09
# 2  A3  47  女 2018-08-10
# 3  A4  41  男 2018-08-11

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   編號      4 non-null      object
#  1   年齡      4 non-null      int64
#  2   性別      4 non-null      object
#  3   註冊時間    4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe()
# Out:
#               年齡
# count   4.000000
# mean   39.500000
# std    16.542874
# min    16.000000
# 25%    34.750000
# 50%    44.000000
# 75%    48.750000
# max    54.000000

# %%
df[["編號"]]
# Out:
#    編號
# 0  A1
# 1  A2
# 2  A3
# 3  A4

# %%
df.iloc[[0,2]]
# Out:
#    編號  年齡 性別       註冊時間
# 0  A1  54  男 2018-08-08
# 2  A3  47  女 2018-08-10

# %%
df.iloc[0:2]
# Out:
#    編號  年齡 性別       註冊時間
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09

# %%
df.iloc[[0,2],[2,3]]
# Out:
#   性別       註冊時間
# 0  男 2018-08-08
# 2  女 2018-08-10

# %%
df.iloc[0:2,[2,3]]
# Out:
#   性別       註冊時間
# 0  男 2018-08-08
# 1  女 2018-08-09

# %%
df.iloc[0:3,1:3]
# Out:
#    年齡 性別
# 0  54  男
# 1  16  女
# 2  47  女
